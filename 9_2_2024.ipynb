# %% [markdown]
# <a href="https://colab.research.google.com/github/LAKSHMIROHI/AI_ML_Avanthi_Rohitha/blob/main/9_2_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
arr = np.array([16,6,21,5.5,6.7,8.9])
max_value=np.max(arr)
min_value=np.min(arr)
mean_value = np.mean(arr)
median_value = np.median(arr)
std_deviation_value = np.std(arr)
print("max:",max_value)
print("min:",min_value)
print("median:",median_value)
print("standard deviation:",std_deviation_value)
# Out:
# max: 21.0
# min: 5.5
# median: 7.800000000000001
# standard deviation: 5.810168289779183

# %%
#mode
from scipy import stats
stats.mode(arr)
# Out:
# ModeResult(mode=5.5, count=1)

# %%
#variance
np.var(arr)
# Out:
# 33.75805555555555

# %%
#simple linear regression
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('/content/canada_per_capita_income.csv')
df
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
# %matplotlib inline
plt.xlabel('year')
plt.ylabel('per capita income')
plt.scatter(df['year'],df['per capita income (US$)'],color='skyblue',marker='+')

# %%
x=df.drop('per capita income (US$)',axis='columns')
x
# Out:
#     year
# 0   1970
# 1   1971
# 2   1972
# 3   1973
# 4   1974
# 5   1975
# 6   1976
# 7   1977
# 8   1978
# 9   1979
# 10  1980
# 11  1981
# 12  1982
# 13  1983
# 14  1984
# 15  1985
# 16  1986
# 17  1987
# 18  1988
# 19  1989
# 20  1990
# 21  1991
# 22  1992
# 23  1993
# 24  1994
# 25  1995
# 26  1996
# 27  1997
# 28  1998
# 29  1999
# 30  2000
# 31  2001
# 32  2002
# 33  2003
# 34  2004
# 35  2005
# 36  2006
# 37  2007
# 38  2008
# 39  2009
# 40  2010
# 41  2011
# 42  2012
# 43  2013
# 44  2014
# 45  2015
# 46  2016

# %%
y = df['per capita income (US$)']
y
# Out:
# 0      3399.299037
# 1      3768.297935
# 2      4251.175484
# 3      4804.463248
# 4      5576.514583
# 5      5998.144346
# 6      7062.131392
# 7      7100.126170
# 8      7247.967035
# 9      7602.912681
# 10     8355.968120
# 11     9434.390652
# 12     9619.438377
# 13    10416.536590
# 14    10790.328720
# 15    11018.955850
# 16    11482.891530
# 17    12974.806620
# 18    15080.283450
# 19    16426.725480
# 20    16838.673200
# 21    17266.097690
# 22    16412.083090
# 23    15875.586730
# 24    15755.820270
# 25    16369.317250
# 26    16699.826680
# 27    17310.757750
# 28    16622.671870
# 29    17581.024140
# 30    18987.382410
# 31    18601.397240
# 32    19232.175560
# 33    22739.426280
# 34    25719.147150
# 35    29198.055690
# 36    32738.262900
# 37    36144.481220
# 38    37446.486090
# 39    32755.176820
# 40    38420.522890
# 41    42334.711210
# 42    42665.255970
# 43    42676.468370
# 44    41039.893600
# 45    35175.188980
# 46    34229.193630
# ...

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.predict([[2024]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([44602.55439531])

# %%
model.score(x,y)
# Out:
# 0.890916917957032

# %%
model.coef_
# Out:
# array([828.46507522])

# %%
model.intercept_
# Out:
# -1632210.7578554575

# %%
d = pd.read_csv('/content/areas.csv')
d.head()
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300
# 3  3540
# 4  4120

# %%
p = model.predict(d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-77d083697d9c> in <cell line: 1>()
# ----> 1 p = model.predict(d)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     352             Returns predicted values.
#     353         """
# --> 354         return self._decision_function(X)
#     355
#     356     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     335         check_is_fitted(self)
#     336
# --> 337         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     338         return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     339
#
# ...

# %%
d['prices'] = p
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-97debbce0bc4> in <cell line: 1>()
# ----> 1 d['prices'] = p
#
# NameError: name 'p' is not defined

# %%
d.to_csv('prediction.csv', index=False)

# %%
d = pd.read_csv('/content/prediction.csv')

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('prices')
plt.scatter(df.area,df.price,color='skyblue',marker='+')
plt.plot(d.area,model.predict(d[['area']]),color='blue')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-bd66180b9571> in <cell line: 4>()
#       2 plt.xlabel('area')
#       3 plt.ylabel('prices')
# ----> 4 plt.scatter(df.area,df.price,color='skyblue',marker='+')
#       5 plt.plot(d.area,model.predict(d[['area']]),color='blue')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'area'

# %%
df=pd.read_csv('/content/carprices.csv')
df
# Out:
#                 Car Model  Mileage  Sell Price($)  Age(yrs)
# 0                  BMW X5    69000          18000         6
# 1                  BMW X5    35000          34000         3
# 2                  BMW X5    57000          26100         5
# 3                  BMW X5    22500          40000         2
# 4                  BMW X5    46000          31500         4
# 5                 Audi A5    59000          29400         5
# 6                 Audi A5    52000          32000         5
# 7                 Audi A5    72000          19300         6
# 8                 Audi A5    91000          12000         8
# 9   Mercedez Benz C class    67000          22000         6
# 10  Mercedez Benz C class    83000          20000         7
# 11  Mercedez Benz C class    79000          21000         7
# 12  Mercedez Benz C class    59000          33000         5

# %%
dummies = pd.get_dummies(df['Car Model'])
dummies
# Out:
#     Audi A5  BMW X5  Mercedez Benz C class
# 0         0       1                      0
# 1         0       1                      0
# 2         0       1                      0
# 3         0       1                      0
# 4         0       1                      0
# 5         1       0                      0
# 6         1       0                      0
# 7         1       0                      0
# 8         1       0                      0
# 9         0       0                      1
# 10        0       0                      1
# 11        0       0                      1
# 12        0       0                      1

# %%
merged = pd.concat([df,dummies], axis='columns')
merged
# Out:
#                 Car Model  Mileage  Sell Price($)  Age(yrs)  Audi A5  BMW X5  \
# 0                  BMW X5    69000          18000         6        0       1
# 1                  BMW X5    35000          34000         3        0       1
# 2                  BMW X5    57000          26100         5        0       1
# 3                  BMW X5    22500          40000         2        0       1
# 4                  BMW X5    46000          31500         4        0       1
# 5                 Audi A5    59000          29400         5        1       0
# 6                 Audi A5    52000          32000         5        1       0
# 7                 Audi A5    72000          19300         6        1       0
# 8                 Audi A5    91000          12000         8        1       0
# 9   Mercedez Benz C class    67000          22000         6        0       0
# 10  Mercedez Benz C class    83000          20000         7        0       0
# ...

# %%
final = merged.drop(['Car Model', 'Mileage'], axis='columns')
final
# Out:
#     Sell Price($)  Age(yrs)  Audi A5  BMW X5  Mercedez Benz C class
# 0           18000         6        0       1                      0
# 1           34000         3        0       1                      0
# 2           26100         5        0       1                      0
# 3           40000         2        0       1                      0
# 4           31500         4        0       1                      0
# 5           29400         5        1       0                      0
# 6           32000         5        1       0                      0
# 7           19300         6        1       0                      0
# 8           12000         8        1       0                      0
# 9           22000         6        0       0                      1
# 10          20000         7        0       0                      1
# 11          21000         7        0       0                      1
# 12          33000         5        0       0                      1

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
x = final.drop(['Sell Price($)'], axis='columns')
y = final['Sell Price($)']

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.predict([[3333,0,0,1]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([-18659027.99999999])

# %%
final
# Out:
#     Sell Price($)  Age(yrs)  Audi A5  BMW X5  Mercedez Benz C class
# 0           18000         6        0       1                      0
# 1           34000         3        0       1                      0
# 2           26100         5        0       1                      0
# 3           40000         2        0       1                      0
# 4           31500         4        0       1                      0
# 5           29400         5        1       0                      0
# 6           32000         5        1       0                      0
# 7           19300         6        1       0                      0
# 8           12000         8        1       0                      0
# 9           22000         6        0       0                      1
# 10          20000         7        0       0                      1
# 11          21000         7        0       0                      1
# 12          33000         5        0       0                      1

# %%
model.score(x,y)
# Out:
# 0.9315851574179888

# %%
model.predict([[3400,0,0,1]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([-19035299.99999999])

# %%
model.predict([[2800,0,1,0]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([-15672415.99999999])
